# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from dotenv import load_dotenv
from scripts.ingest_data import *
import os
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency, mannwhitneyu, fisher_exact
from scripts.stats import *
load_dotenv()  # looks for .env in the current/parent dirs
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# True

# %%
main_sheet = read_csv("data/main_sheet/main_sheet_19.04.26.csv")\
    .pipe(clean_columns)\
    .pipe(calculate_columns)\
    .pipe(rename_columns)
main_sheet.head(5)
# Out:
# /Users/hirsh/Documents/GLADR/scripts/ingest_data.py:39: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   calculated[dob_col] = pd.to_datetime(calculated[dob_col], errors='coerce')
# /Users/hirsh/Documents/GLADR/scripts/ingest_data.py:40: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   calculated[presentation_col] = pd.to_datetime(calculated[presentation_col], errors='coerce')
#   contributor qmc_local  k_number        dob sex presentation_date  \
# 0       Hirsh       Yes  K1279654 1974-02-19   F        2023-10-18
# 1       Hirsh        No  K3646667 2003-06-13   M        2023-10-25
# 2       Hirsh       Yes  K0611148 1964-01-05   F        2023-09-12
# 3       Hirsh       Yes  K1463292 1957-04-26   M        2023-09-15
# ...

# %%
local_cohort = main_sheet[main_sheet["local"]=="yes"]
non_local_cohort = main_sheet[main_sheet["local"]=="no"]
print(f"Local cohort size: {len(local_cohort)}\
      Non-local cohort size: {len(non_local_cohort)}")
print(f"Local mean age: {local_cohort['presentation_age'].mean():.2f} \
      Non-local mean age: {non_local_cohort['presentation_age'].mean():.2f} \n\
      StdDev: {local_cohort['presentation_age'].std():.2f} \
      StdDev: {non_local_cohort['presentation_age'].std():.2f}")
# Out:
# Local cohort size: 44      Non-local cohort size: 20
# Local mean age: 54.18       Non-local mean age: 55.80
#       StdDev: 16.93       StdDev: 14.53

# %%
neutrophils_recorded = main_sheet[main_sheet["neutrophils"].notna()]
neutrophils_recorded["wbc_ratio"] = neutrophils_recorded["neutrophils"] / neutrophils_recorded["lymphocytes"]
compare_local(neutrophils_recorded, "wbc_ratio")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[75], line 3
#       1 neutrophils_recorded = main_sheet[main_sheet["neutrophils"].notna()]
#       2 neutrophils_recorded["wbc_ratio"] = neutrophils_recorded["neutrophils"] / neutrophils_recorded["lymphocytes"]
# ----> 3 compare_local(neutrophils_recorded, "wbc_ratio")
#
# NameError: name 'compare_local' is not defined
