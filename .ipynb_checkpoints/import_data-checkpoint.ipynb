# %%
import pandas as pd

# %%
def read_data(data_loc = "data/main_sheet.csv"):
    main_sheet_whole = pd.read_csv("data/main_sheet.csv")
    main_sheet = main_sheet_whole[main_sheet_whole['DOB'].notna()]
    for row in main_sheet.intertuples(index=False):
        print(patient)
    return main_sheet

# %%
main_sheet = read_data()
main_sheet
# Out:
# QMC Local
# k-number
# DOB
# Sex
# Presentation Date
# Age at presentation
# Neutrophils (presentation)
# Lymphocytes (presentation)
# First contrast MRI
# Side
# Lobe
# Peri-ventricular
# Multifocal
# Resection
# Post-op MRI Date
# 5-ALA
# Residual contrast enhancement
# Radiotherapy
# TMZ
# First recurrence evidence
# Recurrence side
# Recurrence lobe
# Local
# DOD
#   QMC Local  k-number         DOB Sex Presentation Date  Age at presentation  \
# 0       Yes  K1279654  19/02/1974   F        18/10/2023                  NaN
# 1        No  K3646667   13/6/2003   M        25/10/2023                  NaN
# 2       Yes  K0611148    1/5/1964   F         12/9/2023                  NaN
# 3       Yes  K1463292   26/4/1957   M         15/9/2023                  NaN
# 4       Yes  K0501346   21/8/1973   M          6/9/2023                  NaN
#
#    Neutrophils (presentation)  Lymphocytes (presentation) First contrast MRI  \
# ...
